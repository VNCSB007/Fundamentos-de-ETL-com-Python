# %% [markdown]
# este é um teste para poder utilizar o JupyterLabs nas minhas aulas sobre ETL em Python

# %% [raw]
# O "mais" no topo da página se cria uma nova linha de comando para escrever o script que eu quiser

# %% [markdown]
# O Disquete ali em cima salva o código dentro do Laboratório que eu estiver usando

# %% [markdown]
# Para devidamente ter as linhas de código salva em meus computador, é preciso fazer o Download

# %% [markdown]
# O GitHub serve para matar dúvidas sobre como melhor utilizar o JupyterLab

# %% [markdown]
# Finalmente, a opção no final da barra de ferramentas define se o campo em que se está trabalhando é Code, Markdown (text estético) ou Raw (text)

# %%
4+5
# Out:
# 9

# %%
5%2
# Out:
# 1

# %%
x = "feito"
c = "comentários"
b = "bora"
n = "trabalhar"
print(f"{x} os {c}, {b} {n}")
# Out:
# feito os comentários, bora trabalhar
