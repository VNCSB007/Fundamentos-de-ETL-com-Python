# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep = ";", parse_dates = ['ocorrencia_dia'], dayfirst = True)
df.replace(["***", "****", "*****", "!###", "####" "NULL"], pd.NA, inplace = True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.loc[1,"ocorrencia_cidade"]
# Out:
# 'BELÉM'

# %%
df.loc[(5, 10, 3333),]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 5                 39807               39807               39807
# 10                39789               39789               39789
# 3333              53487               53487               53487
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 5                  39807               39807                INCIDENTE
# 10                 39789               39789                INCIDENTE
# 3333               53487               53487                 ACIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude     ocorrencia_cidade  \
# 5                    ***                  ***              SALVADOR
# 10                   NaN                  NaN      SÃO PEDRO DO SUL
# 3333      -10.5972222222             -44.3925  SANTA RITA DE CÁSSIA
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 5               BA  ...     2010-01-06        17:53:00
# 10              RS  ...     2010-01-10        21:30:00
# 3333            BA  ...     2015-09-19        20:30:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 5                               ***                 NaN
# 10                              ***                 NaN
# 3333                            NaN          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 5                            NaN                            NÃO
# 10                           NaN                            NÃO
# 3333           A-125/CENIPA/2015                            SIM
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 5                          NaN                   0                          1
# 10                         NaN                   0                          1
# 3333                2016-06-16                   0                          1
#
#       ocorrencia_saida_pista
# 5                        NÃO
# 10                       NÃO
# 3333                     SIM
#
# [3 rows x 22 columns]

# %%
df.loc[:,"codigo_ocorrencia"]
# Out:
# 0       40211
# 1       40349
# 2       40351
# 3       39527
# 4       40324
#         ...
# 5747    79804
# 5748    79757
# 5749    79802
# 5750    79756
# 5751    79844
# Name: codigo_ocorrencia, Length: 5752, dtype: int64

# %%
df.ocorrencia_classificacao.is_unique
# Out:
# False

# %%
df.set_index('codigo_ocorrencia', inplace = True)

# %%
df.tail(3)
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 79802                           79802               79802               79802
# 79756                           79756               79756               79756
# 79844                           79844               79844               79844
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 79802                           79802                INCIDENTE
# 79756                           79756          INCIDENTE GRAVE
# 79844                           79844                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade  \
# codigo_ocorrencia
# 79802                          -22.81      -43.25055555555    RIO DE JANEIRO
# 79756                      -22.507222           -54.364167         VICENTINA
# 79844                        -22,9875               -43,37    RIO DE JANEIRO
#
#                   ocorrencia_uf ocorrencia_pais  ... ocorrencia_dia  \
# codigo_ocorrencia                                ...
# 79802                        RJ          BRASIL  ...     2020-12-30
# 79756                        MS          BRASIL  ...     2020-12-31
# 79844                        RJ          BRASIL  ...     2020-12-31
#
#                   ocorrencia_hora investigacao_aeronave_liberada  \
# codigo_ocorrencia
# 79802                    00:54:00                            SIM
# 79756                    09:00:00                            SIM
# 79844                    13:24:00                            SIM
#
#                   investigacao_status divulgacao_relatorio_numero  \
# codigo_ocorrencia
# 79802                      FINALIZADA                         ***
# 79756                      FINALIZADA                         ***
# 79844                      FINALIZADA                         ***
#
#                   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# codigo_ocorrencia
# 79802                                        NÃO                       NaN
# 79756                                        NÃO                       NaN
# 79844                                        NÃO                       NaN
#
#                   total_recomendacoes  total_aeronaves_envolvidas  \
# codigo_ocorrencia
# 79802                               0                           1
# 79756                               0                           1
# 79844                               0                           1
#
#                    ocorrencia_saida_pista
# codigo_ocorrencia
# 79802                                 NÃO
# 79756                                 NÃO
# 79844                                 NÃO
#
# [3 rows x 21 columns]

# %%
df.loc[79802]
# Out:
# codigo_ocorrencia1                              79802
# codigo_ocorrencia2                              79802
# codigo_ocorrencia3                              79802
# codigo_ocorrencia4                              79802
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                            -22.81
# ocorrencia_longitude                  -43.25055555555
# ocorrencia_cidade                      RIO DE JANEIRO
# ocorrencia_uf                                      RJ
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             SBGL
# ocorrencia_dia                    2020-12-30 00:00:00
# ocorrencia_hora                              00:54:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       ***
# divulgacao_relatorio_publicado                    NÃO
# divulgacao_dia_publicacao                         NaN
# total_recomendacoes                                 0
# total_aeronaves_envolvidas                          1
# ocorrencia_saida_pista                            NÃO
# Name: 79802, dtype: object

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
#
# [5752 rows x 9 columns]

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 5747              79804               79804               79804
# 5748              79757               79757               79757
# 5749              79802               79802               79802
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 5747               79804               79804                INCIDENTE
# 5748               79757               79757          INCIDENTE GRAVE
# 5749               79802               79802                INCIDENTE
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude  ocorrencia_cidade  \
# 5747      -23.0069444444       -47.1344444444           CAMPINAS
# 5748          -10.804722           -49.756389  LAGOA DA CONFUSÃO
# 5749              -22.81      -43.25055555555     RIO DE JANEIRO
# 5750          -22.507222           -54.364167          VICENTINA
# 5751            -22,9875               -43,37     RIO DE JANEIRO
#
#      ocorrencia_uf  ... ocorrencia_hora investigacao_aeronave_liberada  \
# 5747            SP  ...        19:00:00                            SIM
# 5748            TO  ...        18:30:00                            SIM
# 5749            RJ  ...        00:54:00                            SIM
# 5750            MS  ...        09:00:00                            SIM
# 5751            RJ  ...        13:24:00                            SIM
#
#      investigacao_status divulgacao_relatorio_numero  \
# 5747          FINALIZADA                         ***
# 5748          FINALIZADA                         ***
# 5749          FINALIZADA                         ***
# 5750          FINALIZADA                         ***
# 5751          FINALIZADA                         ***
#
#      divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 5747                            NÃO                       NaN
# 5748                            NÃO                       NaN
# 5749                            NÃO                       NaN
# 5750                            NÃO                       NaN
# 5751                            NÃO                       NaN
#
#      total_recomendacoes total_aeronaves_envolvidas ocorrencia_saida_pista  \
# 5747                   0                          1                    NÃO
# 5748                   0                          1                    NÃO
# 5749                   0                          1                    NÃO
# 5750                   0                          1                    NÃO
# 5751                   0                          1                    NÃO
#
#       ocorrencia_uf_bkp
# 5747                 SP
# 5748                 TO
# 5749                 RJ
# 5750                 MS
# 5751                 RJ
#
# [5 rows x 23 columns]

# %%
df.loc[0, "ocorrencia_latitude"] = ''

# %%
df['codigo_ocorrencia1_bkp'] = df.codigo_ocorrencia1

# %%
df.loc[df.ocorrencia_uf == "SP", ['ocorrencia_classificacao']] = "GRAVE"
# Out:
#      ocorrencia_classificacao
# 11                      GRAVE
# 16                      GRAVE
# 18                      GRAVE
# 26                      GRAVE
# 27                      GRAVE
# ...                       ...
# 5704                    GRAVE
# 5705                    GRAVE
# 5715                    GRAVE
# 5742                    GRAVE
# 5747                    GRAVE
#
# [1373 rows x 1 columns]

# %%
275/1373
# Out:
# 0.20029133284777859

# %% [markdown]
# Limpando dados que não foram informados:
#
# ocorrencia_uf
#
# "***"
#
# ocorrencia_aerodromo
#
# "###!"
# "####"
# "_4_asteriscos_"
# "_5_asteriscos_"
#
# ocorrencia_hora
#
# "NULL"

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df.loc[df.ocorrencia_aerodromo == "****", ["ocorrencia_aerodromo"]] = pd.NA
df.loc[df.ocorrencia_aerodromo == "*****", ["ocorrencia_aerodromo"]] = pd.NA
df.loc[df.ocorrencia_aerodromo == "####", ["ocorrencia_aerodromo"]] = pd.NA
df.loc[df.ocorrencia_aerodromo == "###!", ["ocorrencia_aerodromo"]] = pd.NA

# %%
df.replace(["***", "****", "*****", "!###", "####" "NULL"], pd.NA, inplace = True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 <NA>     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0           12:00:00                    0                        0
# 1           11:05:00                    0                        0
# 2           03:00:00                    0                        0
# 3           17:30:00                    0                        0
# 4           19:25:00                    0                        0
# ...              ...                  ...                      ...
# 5747        19:00:00                    0                        0
# 5748        18:30:00                    0                        0
# 5749        00:54:00                    0                        0
# 5750        09:00:00                    0                        0
# 5751        13:24:00                    0                        0
#
# [5752 rows x 10 columns]

# %%
df.drop(['total_recomendacoes_bkp'], axis = 1, inplace = True)
